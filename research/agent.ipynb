# %%
from qdrant_client import QdrantClient

qdrant_client = QdrantClient(url="http://localhost:6333")

from langchain_gigachat import GigaChatEmbeddings
import os

giga_embeddings =  GigaChatEmbeddings(credentials=os.environ["GIGA_CREDENTIALS"], model="EmbeddingsGigaR", verify_ssl_certs=False)

# %%
from  langchain_qdrant import Qdrant

# %%
from langchain_core.documents import Document
import pandas as pd

pdf_df = pd.read_csv("data/pdf_df.csv", index_col=0)
threads_df = pd.read_csv("data/threads.csv", index_col=0)
vk_chunks_df = pd.read_csv("data/vk_chunks_df.csv",  index_col=0)

# %%
vector_store = Qdrant(client=qdrant_client,  embeddings=giga_embeddings)
vector_store = vector_store.from_documents([Document(metadata=a.to_dict(), page_content=a.chunk_text) for i, a in pdf_df.iterrows()], embedding=giga_embeddings)

# %%
vector_store.
# Out:
# [Document(metadata={'doc_name': 'Правила Приема(Министерские)', 'chunk_id': 2, 'chunk_text': 'федеральных государственных органов, указанных в части 1 статьи 81 Федерального закона от 29 декабря 2012 г. № 273-ФЗ «Об образовании в Российской Федерации» 2 (далее - Федеральный закон № 273-ФЗ), устанавливаются указанными федеральными государственными органами1. 4. Прием на обучение осуществляется на первый курс. 5. Прием на обучение осуществляется: по программам бакалавриата и программам специалитета - при наличии у поступающих среднего общего образования, или среднего профессионального образования, или высшего образования; по программам магистратуры - при наличии у поступающих высшего образования. Наличие образования подтверждается документами об образовании или об образовании и о квалификации, выдаваемыми лицам, успешно прошедшим государственную итоговую аттестацию либо итоговую аттестацию (далее - документы об образовании). 6. Поступающим необходимо иметь: 1) для поступления на обучен
# ...

# %%
threads_df
# Out:
#        thread_id  root_global_id  turns  \
# 0              1      chat2021_6      1
# 1              2      chat2021_7      1
# 2              3     chat2021_10      1
# 3              4     chat2021_11      1
# 4              5     chat2021_12      1
# ...          ...             ...    ...
# 42977      42978  chat2024_70489      1
# 42978      42979  chat2024_70490      1
# 42979      42980  chat2024_70505      1
# 42980      42981  chat2024_70507      2
# 42981      42982  chat2024_70511      1
#
#                                             dialog_plain  \
# 0      Порядок распределения по кафедрам/направлениям...
# 1      Порядок получения общежития При зачислении мес...
# 2      Возможность заселения в одну комнату знакомых/...
# 3      Перевод между направлениями 8 института. Перев...
# 4      Программа обучения программированию на 1 курсе...
# ...                                                  ...
# 42977  👀 Студенты, а вы помните крышесносную приемную...
# ...

# %%
from yandex_chain import YandexEmbeddings

import os
embeddings = YandexEmbeddings(folder_id=os.environ["FOLDER_ID"], api_key=os.environ["API_KEY"])
print(embeddings.embed_query("How are you today?"))
# Out:
# [0.0259246826171875, 0.006649017333984375, 0.04736328125, -0.09912109375, -0.080810546875, -0.07049560546875, -0.136962890625, -0.10943603515625, 0.04229736328125, -0.01727294921875, 0.10272216796875, -0.04644775390625, 0.0430908203125, -0.00682830810546875, -0.0323486328125, -0.0238037109375, 0.07867431640625, 0.0016660690307617188, -0.07305908203125, -0.1259765625, -0.0491943359375, 0.036651611328125, -0.01450347900390625, 0.042022705078125, -0.03192138671875, 0.008514404296875, 0.029693603515625, 0.0751953125, 0.0909423828125, -0.0528564453125, -0.047210693359375, 0.0341796875, -0.0255279541015625, 0.060791015625, -0.009979248046875, -0.08563232421875, -0.0122528076171875, 0.02734375, -0.00302886962890625, 0.085205078125, -0.11236572265625, 0.0335693359375, 0.055267333984375, 0.022674560546875, 0.0162506103515625, 0.007022857666015625, -0.0091552734375, -1.5020370483398438e-05, 0.040283203125, 0.018310546875, -0.051361083984375, -0.069091796875, -0.03704833984375, 0.00381278991699
# ...

# %%
from yandex_chain import YandexEmbeddings

import os
embeddings = YandexEmbeddings(folder_id=os.environ["folder_id"], api_key=os.environ["api_key"])
print(embeddings.embed_query("How are you today?"))
# Out:
# [0.0259246826171875, 0.006649017333984375, 0.04736328125, -0.09912109375, -0.080810546875, -0.07049560546875, -0.136962890625, -0.10943603515625, 0.04229736328125, -0.01727294921875, 0.10272216796875, -0.04644775390625, 0.0430908203125, -0.00682830810546875, -0.0323486328125, -0.0238037109375, 0.07867431640625, 0.0016660690307617188, -0.07305908203125, -0.1259765625, -0.0491943359375, 0.036651611328125, -0.01450347900390625, 0.042022705078125, -0.03192138671875, 0.008514404296875, 0.029693603515625, 0.0751953125, 0.0909423828125, -0.0528564453125, -0.047210693359375, 0.0341796875, -0.0255279541015625, 0.060791015625, -0.009979248046875, -0.08563232421875, -0.0122528076171875, 0.02734375, -0.00302886962890625, 0.085205078125, -0.11236572265625, 0.0335693359375, 0.055267333984375, 0.022674560546875, 0.0162506103515625, 0.007022857666015625, -0.0091552734375, -1.5020370483398438e-05, 0.040283203125, 0.018310546875, -0.051361083984375, -0.069091796875, -0.03704833984375, 0.00381278991699
# ...

# %%
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.tools import tool



llm = ChatOpenAI(
    model="gpt://" + os.environ["folder_id"] + "/yandexgpt/rc",
    api_key=os.environ["api_key"],
    base_url="https://llm.api.cloud.yandex.net/v1"
)

@tool
def search(query:str) -> str:
    """Ищет информацию нужную пользователю"""
    return f"Крутая  информация про {query}"

# %%
llm_wth_tools = llm.bind_tools(tools=[search])

# %%
search.invoke(llm_wth_tools.invoke("Найди инфу про бобров").tool_calls[0])
# Out:
# ToolMessage(content='Крутая  информация про бобры', name='search', tool_call_id='search')

# %%
from langchain_community.vectorstores import Qdrant
from langchain_openai import OpenAIEmbeddings
from langchain.retrievers.multi_query import MultiQueryRetriever
from langchain.schema import Document
from qdrant_client import QdrantClient
from qdrant_client.models import Distance, VectorParams, SparseVectorParams, SparseIndices
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
from typing import List, Tuple, Optional

# Инициализация клиента Qdrant
client = QdrantClient(location=":memory:")  # или используйте URL для удаленного сервера

# Создание коллекции с поддержкой двух типов векторов: плотного (для векторного поиска) и разреженного (для BM25)
collection_name = "hybrid_search_collection"

if not client.collection_exists(collection_name):
    client.create_collection(
        collection_name=collection_name,
        vectors_config={
            "dense": VectorParams(size=1536, distance=Distance.COSINE)  # Размер зависит от модели эмбеддинга
        },
        sparse_vectors_config={
            "sparse_bm25": SparseVectorParams(index=SparseIndices.ON)
        }
    )

# Инициализация эмбеддингов (например, OpenAI)
embeddings = OpenAIEmbeddings(model="text-embedding-ada-002")

# TF-IDF для имитации BM25 (упрощённая версия)
tfidf_vectorizer = TfidfVectorizer()

def _generate_sparse_vector(text: str) -> dict:
    """Генерирует разреженный вектор для текста (имитация BM25)."""
    tfidf_matrix = tfidf_vectorizer.transform([text])
    indices = tfidf_matrix.indices.tolist()
    values = tfidf_matrix.data.tolist()
    return {"indices": indices, "values": values}

def add_documents_to_qdrant(documents: List[Document]):
    """Добавляет документы в Qdrant с плотными и разреженными векторами."""
    texts = [doc.page_content for doc in documents]
    metadatas = [doc.metadata for doc in documents]

    # Генерация плотных векторов
    dense_vectors = embeddings.embed_documents(texts)

    # Обучение TF-IDF на всех текстах
    tfidf_vectorizer.fit(texts)

    # Генерация разреженных векторов
    sparse_vectors = [_generate_sparse_vector(text) for text in texts]

    # Добавление документов в Qdrant
    client.upsert(
        collection_name=collection_name,
        points=[
            {
                "id": i,
                "vector": {
                    "dense": dense_vectors[i],
                    "sparse_bm25": sparse_vectors[i]
                },
                "payload": {
                    "text": texts[i],
                    "metadata": metadatas[i]
                }
            } for i in range(len(texts))
        ]
    )

def vector_store_search(query: str, top_k: int = 5) -> List[Document]:
    """
    Выполняет гибридный поиск в Qdrant с использованием MultiQuery и BM25.
    """

    # Инициализация векторного хранилища с несколькими типами векторов
    db = Qdrant(
        client=client,
        collection_name=collection_name,
        embeddings=embeddings,
        vector_name="dense"
    )

    # Создание MultiQueryRetriever
    retriever = MultiQueryRetriever.from_llm(
        retriever=db.as_retriever(search_kwargs={"k": top_k}),
        llm="gpt-3.5-turbo"  # Здесь можно указать конкретный LLM для генерации альтернативных запросов
    )

    # Генерация нескольких запросов
    alternative_queries = retriever.generate_queries(query)

    # Сбор всех результатов из разных типов поиска
    results = []

    for alt_query in alternative_queries:
        # Плотный векторный поиск
        dense_results = db.similarity_search(alt_query, k=top_k, vector_name="dense")
        results.extend(dense_results)

        # Разреженный (BM25-подобный) поиск
        sparse_vector = _generate_sparse_vector(alt_query)
        sparse_results = client.search(
            collection_name=collection_name,
            query_vector=("sparse_bm25", sparse_vector),
            limit=top_k
        )
        for res in sparse_results:
            payload = res.payload
            doc = Document(page_content=payload["text"], metadata=payload["metadata"])
            results.append(doc)

    # Удаление дубликатов и ранжирование по релевантности
    unique_docs = {}
    for doc in results:
        key = hash(doc.page_content)
        if key not in unique_docs:
            unique_docs[key] = doc

    # Возвращаем топ-K документов
    return list(unique_docs.values())[:top_k]
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[26], line 6
#       4 from langchain.schema import Document
#       5 from qdrant_client import QdrantClient
# ----> 6 from qdrant_client.models import Distance, VectorParams, SparseVectorParams, SparseIndices
#       7 from sklearn.feature_extraction.text import TfidfVectorizer
#       8 import numpy as np
#
# ImportError: cannot import name 'SparseIndices' from 'qdrant_client.models' (/home/lockr/projects/Yandex-multimodal-assistant/.venv/lib/python3.11/site-packages/qdrant_client/models/__init__.py)

# %%
search.invoke("how many topics?")
# Out:
# [QueryResponse(points=[])]

# %%
client.delete_collection("Collection_pdf")
# Out:
# True

# %%
client.create_snapshot("Collection_pdf", wait=False)

# %%
from langchain_community.vectorstores import Qdrant
from langchain_openai import OpenAIEmbeddings
from langchain.retrievers.multi_query import MultiQueryRetriever
from langchain.schema import Document
from qdrant_client import QdrantClient
from qdrant_client.models import Distance, VectorParams, SparseVectorParams, SparseIndices
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
from typing import List, Tuple, Optional

# Инициализация клиента Qdrant
client = QdrantClient(location=":memory:")  # или используйте URL для удаленного сервера

# Создание коллекции с поддержкой двух типов векторов: плотного (для векторного поиска) и разреженного (для BM25)
collection_name = "hybrid_search_collection"

if not client.collection_exists(collection_name):
    client.create_collection(
        collection_name=collection_name,
        vectors_config={
            "dense": VectorParams(size=1536, distance=Distance.COSINE)  # Размер зависит от модели эмбеддинга
        },
        sparse_vectors_config={
            "sparse_bm25": SparseVectorParams(index=SparseIndices.ON)
        }
    )

# Инициализация эмбеддингов (например, OpenAI)
embeddings = OpenAIEmbeddings(model="text-embedding-ada-002")

# TF-IDF для имитации BM25 (упрощённая версия)
tfidf_vectorizer = TfidfVectorizer()

def _generate_sparse_vector(text: str) -> dict:
    """Генерирует разреженный вектор для текста (имитация BM25)."""
    tfidf_matrix = tfidf_vectorizer.transform([text])
    indices = tfidf_matrix.indices.tolist()
    values = tfidf_matrix.data.tolist()
    return {"indices": indices, "values": values}

def add_documents_to_qdrant(documents: List[Document]):
    """Добавляет документы в Qdrant с плотными и разреженными векторами."""
    texts = [doc.page_content for doc in documents]
    metadatas = [doc.metadata for doc in documents]

    # Генерация плотных векторов
    dense_vectors = embeddings.embed_documents(texts)

    # Обучение TF-IDF на всех текстах
    tfidf_vectorizer.fit(texts)

    # Генерация разреженных векторов
    sparse_vectors = [_generate_sparse_vector(text) for text in texts]

    # Добавление документов в Qdrant
    client.upsert(
        collection_name=collection_name,
        points=[
            {
                "id": i,
                "vector": {
                    "dense": dense_vectors[i],
                    "sparse_bm25": sparse_vectors[i]
                },
                "payload": {
                    "text": texts[i],
                    "metadata": metadatas[i]
                }
            } for i in range(len(texts))
        ]
    )

def vector_store_search(query: str, top_k: int = 5) -> List[Document]:
    """
    Выполняет гибридный поиск в Qdrant с использованием MultiQuery и BM25.
    """

    # Инициализация векторного хранилища с несколькими типами векторов
    db = Qdrant(
        client=client,
        collection_name=collection_name,
        embeddings=embeddings,
        vector_name="dense"
    )

    # Создание MultiQueryRetriever
    retriever = MultiQueryRetriever.from_llm(
        retriever=db.as_retriever(search_kwargs={"k": top_k}),
        llm="gpt-3.5-turbo"  # Здесь можно указать конкретный LLM для генерации альтернативных запросов
    )

    # Генерация нескольких запросов
    alternative_queries = retriever.generate_queries(query)

    # Сбор всех результатов из разных типов поиска
    results = []

    for alt_query in alternative_queries:
        # Плотный векторный поиск
        dense_results = db.similarity_search(alt_query, k=top_k, vector_name="dense")
        results.extend(dense_results)

        # Разреженный (BM25-подобный) поиск
        sparse_vector = _generate_sparse_vector(alt_query)
        sparse_results = client.search(
            collection_name=collection_name,
            query_vector=("sparse_bm25", sparse_vector),
            limit=top_k
        )
        for res in sparse_results:
            payload = res.payload
            doc = Document(page_content=payload["text"], metadata=payload["metadata"])
            results.append(doc)

    # Удаление дубликатов и ранжирование по релевантности
    unique_docs = {}
    for doc in results:
        key = hash(doc.page_content)
        if key not in unique_docs:
            unique_docs[key] = doc

    # Возвращаем топ-K документов
    return list(unique_docs.values())[:top_k]
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[26], line 6
#       4 from langchain.schema import Document
#       5 from qdrant_client import QdrantClient
# ----> 6 from qdrant_client.models import Distance, VectorParams, SparseVectorParams, SparseIndices
#       7 from sklearn.feature_extraction.text import TfidfVectorizer
#       8 import numpy as np
#
# ImportError: cannot import name 'SparseIndices' from 'qdrant_client.models' (/home/lockr/projects/Yandex-multimodal-assistant/.venv/lib/python3.11/site-packages/qdrant_client/models/__init__.py)

# %%
"""This module provides example tools for web scraping and search functionality.

It includes a basic Tavily search function (as an example)

These tools are intended as free examples to get started. For production use,
consider implementing more robust and specialized tools tailored to your needs.
"""

from typing import Any, Callable, List, Optional, cast

from langchain_tavily import TavilySearch  # type: ignore[import-not-found]

from react_agent.configuration import Configuration
from langchain_core.tools import tool

from qdrant_client import QdrantClient, models
from yandex_chain import YandexEmbeddings

from langchain_openai import OpenAIEmbeddings
import pandas as pd
client = QdrantClient(url="http://localhost:6333")

import os
from fastembed import TextEmbedding, SparseTextEmbedding

dense_embedding_model = YandexEmbeddings(folder_id=os.environ["folder_id"], api_key=os.environ["api_key"])
bm25_embedding_model = SparseTextEmbedding("Qdrant/bm25")

if not client.collection_exists("Collection_pdf"):
    client.create_collection(
        "Collection_pdf",
        vectors_config={
            "dense": models.VectorParams(
                size=len(dense_embedding_model.embed_document("0")),
                distance=models.Distance.COSINE,
            )
        },
        sparse_vectors_config={
            "sparse": models.SparseVectorParams(
                modifier=models.Modifier.IDF,
            )
        }
    )
    df = pd.DataFrame(pd.read_csv("react_agent/data/final_data_with_topics_nd_preprocess.csv"))
    
    client.upload_collection(
        "Collection_pdf",
        vectors = {
            "dense": dense_embedding_model.embed_documents(df["chunk_text"].tolist()),
            "sparse": bm25_embedding_model.embed(df["chunk_text"].tolist()),
        },
        payload=df.to_dict(),
    )
    
# if not client.collection_exists("Collection_threads"):
#     client.create_collection(
#         "Collection_threads",
#         vectors_config={
#             "dense": models.VectorParams(
#                 size=len(dense_embedding_model.embed_document("0")[0]),
#                 distance=models.Distance.COSINE,
#             )
#         },
#         sparse_vectors_config={
#             "sparse": models.SparseVectorParams(
#                 modifier=models.Modifier.IDF,
#             )
#         }
#     )   
#     df = pd.DataFrame(pd.read_csv("data/pdf_df.csv"))
#     client.upload_collection(
#         "Collection_pdf",
#         vectors = {
#             "dense": dense_embedding_model.embed_documents(df["chunk_text"].tolist()),
#             "sparse": bm25_embedding_model.embed_documents(df["chunk_text"].tolist()),
#         }
#         payload=df.to_dict(),
#     )
    
# if not client.collection_exists("Collection_ocr"):
#     client.create_collection(
#         "Collection_ocr",
#         vectors_config={
#             "dense": models.VectorParams(
#                 size=len(dense_embedding_model.embed_document("0")[0]),
#                 distance=models.Distance.COSINE,
#             )
#         },
#         sparse_vectors_config={
#             "sparse": models.SparseVectorParams(
#                 modifier=models.Modifier.IDF,
#             )
#         }
#     )
#     df = pd.DataFrame(pd.read_csv("data/o.csv"))
#     client.upload_collection(
#         "Collection_pdf",
#         vectors = {
#             "dense": dense_embedding_model.embed_documents(df["chunk_text"].tolist()),
#             "sparse": bm25_embedding_model.embed_documents(df["chunk_text"].tolist()),
#         }
#         payload=df.to_dict(),
#     )

@tool
def search(query:str) -> str:
    """Useful for when you need to answer questions about current events. You should \
    ask targeted questions"""
    dense_query_vector = dense_embedding_model.embed_query(query)
    sparse_query_vector = list(bm25_embedding_model.embed([query]))[0]
    prefetch = [
        models.Prefetch(
            query=dense_query_vector,
            using="dense",
            limit=20,
        ),
        models.Prefetch(
            query=models.SparseVector(**sparse_query_vector.as_object()),
            using="sparse",
            limit=20,
        )
    ]
    results = []
    for i in ["Collection_pdf"]: #, "Collection_threads", "Collection_ocr"]:
        results.append(client.query_points(
            i,
            prefetch=prefetch,
            query=models.FusionQuery(
                fusion=models.Fusion.RRF,
            ),
            with_payload=True,
            limit=10,
        ))
    return results

# %%
search.invoke("how many topics?")
# Out:
# [QueryResponse(points=[])]

# %%
client.delete_collection("Collection_pdf")
# Out:
# True

# %%
client.create_snapshot("Collection_pdf", wait=False)

# %%
from datasets import Dataset
import pandas as pd
df.to_pandas()
# Out:
#        _id       source                                         chunk_text  \
# 0        1  chat2021_10  ### Суть\n\nЧат содержит информацию о задачах ...
# 1        2  chat2021_10  ### Суть\nВ чанке перечислены списки документо...
# 2        3  chat2021_10  ### Суть\nАбитуриент интересуется возможностью...
# 3        4  chat2021_10  ### Суть\n\nОбсуждение условий предоставления ...
# 4        5  chat2021_10  ### Суть\n\nВ чанке обсуждаются рекомендации п...
# ...    ...          ...                                                ...
# 4279  4280    ФРЭЛА МАИ  [ФРЭЛА МАИ 💥 В рамках VI Фестиваля радиоэлектр...
# 4280  4281    ФРЭЛА МАИ  [ФРЭЛА МАИ Уже завтра в 13:00 Василий Егоров, ...
# 4281  4282    ФРЭЛА МАИ  [ФРЭЛА МАИ МАИ приглашает студентов и школьник...
# 4282  4283    ФРЭЛА МАИ  [ФРЭЛА МАИ 🚀 Попробуй свои силы — участвуй в О...
# 4283  4284    ФРЭЛА МАИ  [ФРЭЛА МАИ Маёвцы! Наш товарищ в беде! 😢\nГриг...
#
#                                                  topics
# ...

# %%
"""This module provides example tools for web scraping and search functionality.

It includes a basic Tavily search function (as an example)

These tools are intended as free examples to get started. For production use,
consider implementing more robust and specialized tools tailored to your needs.
"""

from typing import Any, Callable, List, Optional, cast
import json

from react_agent.configuration import Configuration
from langchain_core.tools import tool

from qdrant_client import QdrantClient, models
import pandas as pd
client = QdrantClient("http://localhost:6333")

import os
from fastembed import SparseTextEmbedding
from yandex_cloud_ml_sdk import YCloudML
sdk = YCloudML(folder_id=os.environ["folder_id"], auth=os.environ["api_key"])

dense_query_embedding_model = sdk.models.text_embeddings("query")
dense_doc_embedding_model = sdk.models.text_embeddings("doc")
bm25_embedding_model = SparseTextEmbedding("Qdrant/bm25")

from datasets import Dataset
import tqdm

if not client.collection_exists("Collection_pdf"):
    
    df = Dataset.from_pandas(pd.DataFrame(pd.read_csv("react_agent/data/knowledge_data.csv", header=1, names=["_id", "source", "chunk_text", "topics"])))
    client.create_collection(
        "Collection_pdf",
        vectors_config={
            "dense": models.VectorParams(
                size=len(dense_doc_embedding_model.run("0").embedding),
                distance=models.Distance.COSINE,
            )
        },
        sparse_vectors_config={
            "sparse": models.SparseVectorParams(
                modifier=models.Modifier.IDF,
            )
        }
    )

    batch_size = 4
    for batch in tqdm.tqdm(df.iter(batch_size=batch_size), 
                        total=len(df) // batch_size):
        dense_embeddings =  [dense_doc_embedding_model.run(doc).embedding for doc in batch["chunk_text"]]
        bm25_embeddings = list(bm25_embedding_model.embed(batch["chunk_text"]))
        
        client.upload_points(
            "Collection_pdf",
            points=[
                models.PointStruct(
                    id=int(batch["_id"][i]),
                    vector={
                        "dense": dense_embeddings[i],
                        "sparse": bm25_embeddings[i].as_object(),
                    },
                    payload={
                        "_id": batch["_id"][i],
                        "source": batch["source"][i],
                        "topics": batch["topics"][i],
                        "chunk_text": batch["chunk_text"][i],
                    }
                )
                for i, _ in enumerate(batch["_id"])
            ],
            # We send a lot of embeddings at once, so it's best to reduce the batch size.
            # Otherwise, we would have gigantic requests sent for each batch and we can
            # easily reach the maximum size of a single request.
            batch_size=batch_size,  
        )
        


@tool
def search(query:str) -> str:
    """Useful for when you need to answer questions about current events. You should \
    ask targeted questions"""
    dense_query_vector = dense_query_embedding_model.run(query).embedding
    sparse_query_vector = list(bm25_embedding_model.embed([query]))[0]
    prefetch = [
        models.Prefetch(
            query=dense_query_vector,
            using="dense",
            limit=20,
        ),
        models.Prefetch(
            query=models.SparseVector(**sparse_query_vector.as_object()),
            using="sparse",
            limit=20,
        )
    ]
    results = []
    for col in ["Collection_pdf"]:
        resp = client.query_points(
            col,
            prefetch=prefetch,
            query=models.FusionQuery(
                fusion=models.Fusion.RRF,
            ),
            with_payload=True,
            limit=10,
        )
                
        for point in resp.points:
            results.append(point.payload["chunk_text"])
    print(len(results))
    return "\n".join([20*"=" + f"\n# Источник номер {i+1}\n" + _ for i, _ in enumerate(results)])

# %%
search.invoke("ijdiw")
# Out:
# 10
# ...

# %%
results
# Out:
# ['### Суть\n\nЧат содержит информацию о задачах старосты в МАИ, процессе получения временной регистрации для проживающих в общежитии, экзаменах для направлений ПМИ и ФИИТ в 2020 году, а также о необходимых документах для поступления.\n\n### Ключевые факты\n\n- Староста передаёт информацию от дирекции и преподавателей, отмечает посещаемость и участвует в собраниях старост.\n- Стать старостой можно через выборы или назначение дирекцией.\n- Заселившимся в общежитие МАИ оформляют временную регистрацию.\n- Для направлений ПМИ и ФИИТ в 2020 году были нужны экзамены по русскому языку, математике и физике.\n- Для поступления в МАИ требуются паспорт, аттестат или диплом, СНИЛС, заявление и согласие на обработку персональных данных.\n- При сдаче внутренних экзаменов нужны две чёрно-белые фотографии 4x6 см на матовой бумаге.\n- Справка по форме 086-У нужна только для занятий физической культурой.\n\n### Часто задаваемые вопросы\n\nQ: Нужны ли какие-нибудь справки для поступления в МАИ?\nA: Для 
# ...

# %%
client.create_snapshot("Collection_pdf", wait=True)
# Out:
# SnapshotDescription(name='Collection_pdf-7480808102419119-2025-04-30-14-23-30.snapshot', creation_time='2025-04-30T14:24:05', size=907048960, checksum='b83c95ae3796ef927464f6b55298ca611b2f4584b524ebbbd2678276e67e75eb')

# %%
import requests
from pathlib import Path
try:
    client = client
    snapshot_name = 'Collection_pdf-7480808102419119-2025-04-30-14-23-30.snapshot'

    url = f"http://localhost:6333/collections/Collection_pdf/snapshots/{snapshot_name}"
    headers = {"api-key": ""} if "" else {}
    resp = requests.get(url, headers=headers, stream=True)
    resp.raise_for_status()

    snap_dir = Path(".")
    snap_dir.mkdir(parents=True, exist_ok=True)
    file_path = snap_dir / snapshot_name

    with open(file_path, "wb") as f:
        for chunk in resp.iter_content(chunk_size=8192):
            f.write(chunk)


except Exception as e:
    print(e)

# %%
client._client.openapi_client.client._client.timeout = 600

# %%
                    payload={
                        "_id": batch["_id"][i],
                        "source": batch["source"][i],
                        "topics": batch["topics"][i],
                        "chunk_text": batch["chunk_text"][i],
                    }
